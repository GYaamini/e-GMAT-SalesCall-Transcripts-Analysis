# %%
# %load_ext sql

# %%
import csv, sqlite3, prettytable

prettytable.DEFAULT = 'DEFAULT'

# %%
con = sqlite3.connect("SC_Tdb.db")
cor = con.cursor()

# %%
# %sql sqlite:///SC_Tdb.db

# %%
import pandas as pd
import os

filepath = os.path.join(os.getcwd().split('backend')[0],"e-GMAT_SalesCall_DataAnalysis_80")
filepath
# Out:
# 'C:\\GOWDATA\\PROJECTS\\e-GMAT-SalesCall-Analysis\\e-GMAT_SalesCall_DataAnalysis_80'

# %%
df_data = pd.read_csv(os.path.join(filepath, "combined_dataset_80.csv"))
df_data.head(2)
# Out:
#   transcript_id month  conversion_likelihood  \
# 0  100_20250213   Feb                    0.7
# 1  101_20250212   Feb                    0.8
#
#                                            reasoning  \
# 0  Prospect showed positive emotions (more than 2...
# 1  Prospect showed positive emotion (hope or conf...
#
#                                    emotions_detected location  \
# 0  approval,gratitude,optimism,admiration,optimis...    India
# 1  gratitude,optimism,optimism,optimism,realizati...  No Info
#
#               education                                       organization  \
# 0   b.tech, engineering  UPSC, GMAT, GP, Indian School of Business, CAT...
# 1  engineering, masters                                  PMS, GMAC, CFA L1
#
#                              date  \
# 0  2021, 11 months, 7 to 8 months
# 1               about 1 1/2 years
#
#                            agent_emotions_with_score  \
# 0  Introduction: admiration - 0.72, curiosity - 0...
# ...

# %%
df_data.to_sql("transcripts", con, if_exists="replace", index=False, method="multi")
# Out:
# 142

# %%
# %sql drop table if exists sct_insights
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# []

# %%
# %sql create table sct_insights as select * from transcripts
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# []

# %%
# %sql select * from sct_insights limit 1
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# ...

# %%
# %sql create view overview as select transcript_id,month,conversion_likelihood,reasoning from sct_insights
# Out:
#  * sqlite:///SC_Tdb.db
# (sqlite3.OperationalError) view overview already exists
# [SQL: create view overview as select transcript_id,month,conversion_likelihood,reasoning from sct_insights]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql select * from overview limit 3
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [('100_20250213', 'Feb', 0.7, 'Prospect showed positive emotions (more than 2) during wrap-up/Q&A, Either prospect showed willingness and curiosity in performance/targets discussio ... (43 characters truncated) ... ng price discussion, Agent maintained high confidence or relief near end, Agent catered to the prospect needs with clarity during product explanation'),
#  ('101_20250212', 'Feb', 0.8, 'Prospect showed positive emotion (hope or confidence or etc.) during wrap-up/Q&A, Prospect showed willingness and curiosity in performance/targets di ... (187 characters truncated) ... ng price discussion, Agent maintained high confidence or relief near end, Agent catered to the prospect needs with clarity during product explanation'),
# ...

# %%
# %sql SELECT * FROM overview WHERE LOWER(transcript_id) LIKE LOWER('%100%')
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [('100_20250213', 'Feb', 0.7, 'Prospect showed positive emotions (more than 2) during wrap-up/Q&A, Either prospect showed willingness and curiosity in performance/targets discussio ... (43 characters truncated) ... ng price discussion, Agent maintained high confidence or relief near end, Agent catered to the prospect needs with clarity during product explanation')]

# %%
# %sql SELECT transcript_id, location, education, organization FROM sct_insights WHERE conversion_likelihood < '1.55'
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [('100_20250213', 'India', 'b.tech, engineering', 'UPSC, GMAT, GP, Indian School of Business, CAT, B.Tech, EG Mat, Electronics and Communication, Manhattan Review, PwC India'),
#  ('101_20250212', 'No Info', 'engineering, masters', 'PMS, GMAC, CFA L1'),
#  ('102_20250212', 'No Info', 'No Info', 'GMAT'),
#  ('103_20250212', 'Milan, Rome, US', 'No Info', 'Business School, GMAT, G Mac, IELTS'),
#  ('104_20250212', 'No Info', 'No Info', 'WhatsApp'),
#  ('105_20250215', 'No Info', 'No Info', 'IIM'),
#  ('106_20250215', 'No Info', 'No Info', 'No Info'),
#  ('107_20250215', 'No Info', 'No Info', 'No Info'),
#  ('108_20250216', 'No Info', 'No Info', 'No Info'),
#  ('109_20250216', 'Europe', 'No Info', 'Co Institute of Management, GMAT, HCL Tech'),
#  ('10_20250107', 'No Info', 'No Info', 'No Info'),
#  ('110_20250216', 'No Info', 'No Info', 'No Info'),
#  ('111_20250216', 'No Info', 'No Info', 'CAT'),
#  ('112_20250213', 'No Info', 'No Info', 'Mercy R&D'),
# ...

# %%
# %sql select count(*) as 'conversion_likelihood>0.55' from overview where conversion_likelihood > '0.55'
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [(70,)]

# %%
# %sql select count(*) as 'conversion_likelihood>=0.8' from overview where conversion_likelihood >= '0.8'
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [(15,)]

# %%
# %sql select count(*) as 'conversion_likelihood<0.55' from overview where conversion_likelihood < '0.55'
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [(72,)]

# %%
# %sql select count(*) as 'conversion_likelihood<0.4' from overview where conversion_likelihood < '0.4'
# Out:
#  * sqlite:///SC_Tdb.db
# Done.
# [(19,)]
