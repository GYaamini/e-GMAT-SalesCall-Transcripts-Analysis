# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as snb
import spacy

# %%
"we need", "you need", "we should", "you should", "we will", "you will", "we have to", "you have to"

"if you", "if we", "suppose we", "we can", "you can", 

"is that ok", "does it make sense", "got it", "are we clear", "any questions", "let me know", "anything else", "ask me", "ping me", "contact me"

"looking for", "assistance", "support", "focus"

"price point", "flexible payment", "discount", "discounts"

"send email", "send recording", "email recording", "send study plan", "email the resources", "send the resources"

"going to purchase", "going to buy", "will purchase", "will buy", "make the purchase"

"graduate", "graduated", "studied"

"working", "job"

# %%
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
from sklearn.metrics.pairwise import cosine_similarity
import yake
import numpy as np
import json
# Out:
# WARNING:tensorflow:From D:\InstalledPrograms\Anaconda\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# emotion_tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-emotion")
# emotion_model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-emotion")

emotion_tokenizer = AutoTokenizer.from_pretrained("monologg/bert-base-cased-goemotions-original")
emotion_model = AutoModelForSequenceClassification.from_pretrained("monologg/bert-base-cased-goemotions-original")
emotion_model.eval()

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

keyword_extractor = yake.KeywordExtractor(top=8, stopwords=None)
# EMOTION_LABELS = ['anger', 'joy', 'optimism', 'sadness']
# EMOTION_LABELS = ['eager', 'joy', 'optimism', 'hope', 'anxiety', 'doubt', 'skepticism', 'excitement', 'fear', 'disappointment', 'interest', 
#                   'awkwardeness', 'confusion', 'confidence', 'relief', 'understanding', 'stress']
goemo = load_dataset("go_emotions")
EMOTION_LABELS = goemo['train'].features['labels'].feature.names
# Out:
# tokenizer_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# D:\InstalledPrograms\Anaconda\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\NINAADA\.cache\huggingface\hub\models--monologg--bert-base-cased-goemotions-original. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json:   0%|          | 0.00/1.67k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/9.40k [00:00<?, ?B/s]
# D:\InstalledPrograms\Anaconda\Lib\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\NINAADA\.cache\huggingface\hub\datasets--go_emotions. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# train-00000-of-00001.parquet:   0%|          | 0.00/2.77M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/350k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/347k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/43410 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5426 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5427 [00:00<?, ? examples/s]

# %%
phase_prototypes = {
    "Introduction": ["hello", "welcome", "thanks for joining", "good morning",
                    "graduate", "graduated", "studied", "working", "work", "job", "B.Tech", "engineering", "M.Tech", "MS"],
    "Prospect’s performance": ["last attempt", "attempt", "your performance", "preparation", "percentile", "mock test",
                               "targets", "achievements", "target", "goal", "aiming"],
    "Agent drawing up plan": ["we’ll create a plan", "custom strategy", "roadmap", "approach",
                             "looking for", "assistance", "assist", "support", "focus"],
    "Explaining product": ["our product", "features include", "capabilities", "what it does",
                          "we need", "you need", "we should", "you should", "we will", "you will", "we have to", "you have to",
                          "if you", "if we", "suppose we", "we can", "you can",
                          "quant", "verbal", "insights", "DI", "score", "module", "grade"],
    "Price discussion": ["pricing", "cost", "discount", "offer", "package", 
                         "price point", "flexible payment", "discounts"],
    "Q&A": ["any questions", "feel free to ask", "clarify", "follow-up",
           "is that ok", "does it make sense", "got it", "are we clear", "let me know", "anything else", "ask me", "ping me", "contact me"],
    "Wrap": ["going to purchase", "going to buy", "will purchase", "will buy", "make the purchase", 
             "send email", "send recording", "email recording", "send study plan", "email the resources", "send the resources"]
}
prototype_texts = list(phase_prototypes.keys())
prototype_embeddings = embedding_model.encode([" ".join(v) for v in phase_prototypes.values()])

# %%
def predict_emotions(text):
    inputs = emotion_tokenizer(text, return_tensors="pt", truncation=True)
    with torch.no_grad():
        logits = emotion_model(**inputs).logits
        probs = torch.sigmoid(logits)[0]
    top_idxs = (probs > 0.3).nonzero(as_tuple=True)[0]  # threshold
    emotions = [(EMOTION_LABELS[i], probs[i].item()) for i in top_idxs]
    return emotions

def extract_keywords(text):
    return [kw for kw, _ in keyword_extractor.extract_keywords(text)]

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv("transcripts_better_80.csv").dropna(subset=["text"])
df = df.sort_values(by=["transcript_id", "timestamp"])

# %%
df["text"] = df["text"].str.strip()

# %%
timestamp_ranges = df.groupby('transcript_id')['timestamp'].agg(['min', 'max'])
timestamp_ranges
# Out:
#                     min       max
# transcript_id
# 100_20250213   00:00:02  01:17:17
# 101_20250212   00:00:02  00:58:49
# 102_20250212   00:00:04  00:58:29
# 103_20250212   00:00:03  01:06:40
# 104_20250212   00:00:05  00:41:18
# ...                 ...       ...
# 96_20250211    00:00:02  01:03:27
# 97_20250212    00:00:03  00:53:29
# 98_20250212    00:00:02  00:24:49
# 99_20250211    00:00:02  00:40:38
# 9_20250106     00:00:02  00:29:21
#
# [142 rows x 2 columns]

# %%
SECTION_PERCENTAGES = {
    1: 0.05,   # 5% Introduction
    2: 0.15,   # 15% Prospect’s performance
    3: 0.20,   # 20% Agent drawing up plan
    4: 0.35,   # 35% Explaining product
    5: 0.10,   # 10% Price discussion
    6: 0.10,   # 10% Q&A
    7: 0.05    # 5% Wrap
}

assert sum(SECTION_PERCENTAGES.values()) == 1.0, "Percentages must sum to 100%"

def assign_sections(group):
    group = group.sort_values('timestamp')
    total_rows = len(group)
    
    cumulative_rows = 0
    group['section_number'] = np.nan
    
    for section, pct in SECTION_PERCENTAGES.items():
        start_row = cumulative_rows
        end_row = cumulative_rows + int(round(total_rows * pct))
        
        # Handle last section to include remaining rows (due to rounding)
        if section == 7:
            end_row = total_rows
        
        # section numbers assignment
        group.iloc[start_row:end_row, group.columns.get_loc('section_number')] = section
        cumulative_rows = end_row
    
    return group

# %%
df_sections = df.groupby('transcript_id', group_keys=False).apply(assign_sections)

section_ranges = (df_sections.groupby(['transcript_id', 'section_number'])
    .agg(start_timestamp=('timestamp', 'min'),end_timestamp=('timestamp', 'max'),row_count=('timestamp', 'count')).reset_index()
)
section_ranges
# Out:
#     transcript_id  section_number start_timestamp end_timestamp  row_count
# 0    100_20250213             1.0        00:00:02      00:04:02         42
# 1    100_20250213             2.0        00:04:16      00:15:26        127
# 2    100_20250213             3.0        00:15:29      00:32:19        169
# 3    100_20250213             4.0        00:32:24      01:00:46        296
# 4    100_20250213             5.0        01:00:52      01:08:05         85
# ..            ...             ...             ...           ...        ...
# 989    9_20250106             3.0        00:05:45      00:11:46        105
# 990    9_20250106             4.0        00:11:51      00:22:10        183
# 991    9_20250106             5.0        00:22:11      00:25:17         52
# 992    9_20250106             6.0        00:25:21      00:28:14         52
# 993    9_20250106             7.0        00:28:18      00:29:21         27
#
# [994 rows x 5 columns]

# %%
section_ranges.to_csv("sections_in_transcripts_80.csv", index=False)

# %%
df_sections
# Out:
#       month transcript_id timestamp  \
# 0       Feb  100_20250213  00:00:02
# 1       Feb  100_20250213  00:00:14
# 2       Feb  100_20250213  00:00:14
# 3       Feb  100_20250213  00:00:33
# 4       Feb  100_20250213  00:00:34
# ...     ...           ...       ...
# 79671   Jan    9_20250106  00:29:18
# 79672   Jan    9_20250106  00:29:20
# 79673   Jan    9_20250106  00:29:20
# 79674   Jan    9_20250106  00:29:20
# 79675   Jan    9_20250106  00:29:21
#
#                                                     text predicted_speaker  \
# 0      Matt, so basically I have completed my B.Tech ...          prospect
# 1                                                    OK.             agent
# 2      So after that I have joined PwC India and I ha...          prospect
# 3                                                    OK.             agent
# 4      It was the reason I will tell you it was that ...          prospect
# ...                                                  ...               ...
# 79671                                   Yeah, thank you.          prospect
# 79672                                         Thank you.          prospect
# 79673                                               Bye.          prospect
# 79674                                               Bye.          prospect
# 79675                                               Bye.          prospect
#
#        section_number
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 79671             7.0
# 79672             7.0
# 79673             7.0
# 79674             7.0
# 79675             7.0
#
# [79676 rows x 6 columns]

# %% [markdown]
# ## Clustering and Emotion Detection

# %%
import spacy
import re
nlp = spacy.load("en_core_web_sm")

EDUCATION_KEYWORDS = [
    "high school", "diploma", "bachelor", "bachelors", "b.sc", "b.sc.", "bcom", "b.com", "ba",
    "b.a", "b.e", "b.tech", "m.sc", "m.sc.", "mca", "m.tech", "m.com", "phd", "ph.d",
    "doctorate", "masters", "graduate", "postgraduate", "undergraduate", "engineering", 
    "commerce", "arts", "science", "computer science", "information technology"
]

def extract_education_from_text(text, keywords=EDUCATION_KEYWORDS):
    text = text.lower()
    matches = []
    for keyword in keywords:
        # Use word boundaries to avoid partial matches (e.g., "mba" in "embarrass")
        if re.search(r'\b' + re.escape(keyword) + r'\b', text):
            matches.append(keyword)
    return list(set(matches))

def extract_ner_entities(text):
    doc = nlp(text)
    entities = {
        "location": set(),
        "organization": set(),
        "person": set(),
        "age": set(),
        "date": set(),
        "education": []
    }

    entities['education'] = extract_education_from_text(text)
    
    for ent in doc.ents:
        if ent.label_ in ["GPE", "LOC"]:
            entities["location"].add(ent.text)
        elif ent.label_ == "ORG":
            entities["organization"].add(ent.text)
        elif ent.label_ == "PERSON":
            entities["person"].add(ent.text)
        elif ent.label_ == "DATE":
            if any(char.isdigit() for char in ent.text):
                entities["date"].add(ent.text)
        elif ent.label_ == "AGE":
            entities["age"].add(ent.text)

    return {k: list(v) for k, v in entities.items()}

# %%
results = []
sections_text = []
count = 0

for tid, group in df_sections.groupby("transcript_id"):
    print(tid)
    group = group.sort_values("timestamp").reset_index(drop=True)

    section_data = []
    section_text_data = []
    ner_info = {}

    for section_id in sorted(group['section_number'].unique()):
        phase = prototype_texts[int(section_id) - 1]
        chunk = group[group["section_number"] == section_id]
        chunk_texts = chunk["text"].tolist()
        chunk_speakers = chunk["predicted_speaker"].tolist()

        agent_texts = [txt for txt, spk in zip(chunk_texts, chunk_speakers) if spk == "agent"]
        prospect_texts = [txt for txt, spk in zip(chunk_texts, chunk_speakers) if spk == "prospect"]

        agent_blob = " ".join(agent_texts)
        prospect_blob = " ".join(prospect_texts)

        if int(section_id) == 1:
            ner_info = extract_ner_entities(prospect_blob)

        agent_emotions_predicted = predict_emotions(agent_blob)
        agent_emotions = [e[0] for e in agent_emotions_predicted]
        agent_scores = [e[1] for e in agent_emotions_predicted]

        prospect_emotions_predicted = predict_emotions(prospect_blob)
        prospect_emotions = [e[0] for e in prospect_emotions_predicted]
        prospect_scores = [e[1] for e in prospect_emotions_predicted]

        agent_keywords = extract_keywords(agent_blob)
        prospect_keywords = extract_keywords(prospect_blob)

        section_data.append({
            "section_number": int(section_id),
            "phase": phase,
            "speaker emotion": agent_emotions,
            "speaker emotion_score": agent_scores,
            "speaker keywords": ", ".join(agent_keywords),
            "speaker duration": len(agent_texts),
            "prospect emotion": prospect_emotions,
            "prospect emotion_score": prospect_scores,
            "prospect keywords": ", ".join(prospect_keywords),
            "prospect duration": len(prospect_texts),
            "start_timestamp": chunk["timestamp"].iloc[0],
            "end_timestamp": chunk["timestamp"].iloc[-1]
        })

        section_text_data.append({
            "section_number": int(section_id),
            "phase": phase,
            "agent_text": agent_blob,
            "prospect_text": prospect_blob
        })

    results.append({
        "transcript_id": tid,
        "month": group['month'].iloc[0],
        "sections": section_data
    })
    for ner,val in ner_info.items():
        results[count][ner] = val
    count += 1

    sections_text.append({
        "transcript_id": tid,
        "sections": section_text_data,
    })
# Out:
# 100_20250213
# 101_20250212
# 102_20250212
# 103_20250212
# 104_20250212
# 105_20250215
# 106_20250215
# 107_20250215
# 108_20250216
# 109_20250216
# 10_20250107
# 110_20250216
# 111_20250216
# 112_20250213
# 113_20250217
# 114_20250214
# 115_20250214
# 116_20250217
# 117_20250217
# 118_20250217
# 119_20250217
# 11_20250107
# 120_20250218
# 121_20250218
# 122_20250219
# 123_20250219
# 124_20250219
# 125_20250221
# 126_20250221
# 127_20250222
# 128_20250223
# 129_20250223
# 12_20250107
# 130_20250219
# 131_20250224
# 132_20250224
# 133_20250225
# 134_20250226
# 135_20250226
# 136_20250226
# 137_20250227
# 138_20250226
# 139_20250227
# 13_20250108
# 140_20250227
# 141_20250228
# 142_20250224
# 14_20250110
# 15_20250110
# 16_20250110
# 17_20250110
# 18_20250111
# 19_20250112
# 1_20250101
# 20_20250112
# 21_20250112
# 22_20250112
# 23_20250112
# 24_20250111
# 25_20250110
# 26_20250113
# 27_20250110
# 28_20250113
# 29_20250113
# 2_20250102
# 30_20250114
# 31_20250113
# 32_20250113
# 33_20250114
# 34_20250114
# 35_20250115
# 36_20250114
# 37_20250115
# 38_20250115
# 39_20250116
# 3_20250102
# 40_20250116
# 41_20250117
# 42_20250119
# 43_20250119
# 44_20250119
# 45_20250119
# 46_20250117
# 47_20250120
# 48_20250120
# 49_20250116
# 4_20250103
# 50_20250121
# 51_20250121
# 52_20250121
# 53_20250122
# 54_20250122
# 55_20250122
# 56_20250121
# 57_20250122
# 58_20250120
# 59_20250121
# 5_20250104
# 60_20250124
# 61_20250124
# 62_20250124
# 63_20250127
# 64_20250127
# 65_20250127
# 66_20250128
# 67_20250128
# 68_20250129
# 69_20250130
# 6_20250104
# 70_20250131
# 71_20250129
# 72_20250129
# 73_20250130
# 74_20250202
# 75_20250202
# 76_20250202
# 77_20250203
# 78_20250204
# 79_20250204
# 7_20250105
# 80_20250204
# 81_20250205
# 82_20250205
# 83_20250205
# 84_20250206
# 85_20250206
# 86_20250207
# 87_20250207
# 88_20250207
# 89_20250208
# 8_20250105
# 90_20250208
# 91_20250208
# 92_20250208
# 93_20250210
# 94_20250210
# 95_20250211
# 96_20250211
# 97_20250212
# 98_20250212
# 99_20250211
# 9_20250106

# %%
with open("transcript_analysis_sections_80.json", "w") as f:
    json.dump(results, f, indent=2)

with open("transcript_sections_texts_80.json", "w") as f:
    json.dump(sections_text, f, indent=2)

# %% [markdown]
# ## Make transcript text database friendly

# %%
import json

with open("transcript_sections_texts_80.json", "r", encoding="utf-8") as f:
    transcripts = json.load(f)

# %%
simplified_data = []

for transcript in transcripts:
    tid = transcript.get("transcript_id")
    sections = transcript.get("sections", [])
    
    full_text = ""
    for sec in sections:
        phase = sec.get("phase", "")
        agent_text = sec.get("agent_text", "")
        prospect_text = sec.get("prospect_text", "")
        full_text += f"{phase}\nAgent:\n{agent_text.strip()}\nProspect:\n{prospect_text.strip()}\n\n"

    simplified_data.append({
        "transcript_id": tid,
        "transcript_text": full_text.strip()
    })

# %%
def format_view(text):
    lines = text.split('\n')
    formated_view = []

    for line in lines:
        line = line.strip()
        if line.startswith('*'):
            line = '* ' + line[1:].strip()
        formated_view.append(line)
    return '\n'.join(formated_view)

# %%
print(format_view(simplified_data[0]['transcript_text']))
# Out:
# Introduction
# Agent:
# OK. OK. Yes, I mean I'm not sure if you are familiar with that if you are from India or I am from India, Subhanswar, OK, then you would be familiar with that. I would not take the suggestion or advice from your end. Correct, Correct. So yeah, if you're on sabbatical, it's not that, you know, then you will be able to put in more time on a daily basis compared to the folks who are in a full time job. So yes, we will work that out and I'm going to create a planner. So , before we start, I know that you're looking for an executive MBA. Your preferences are IIMA and IIMC. And did you say ISB as well? So these are the three colleges of your preference. , My one question would be is that how did you get to know about EG MAT? Great, great. So how did you do the analysis? Did you find us on Google? And who did you speak to? OK. Yeah. Have you heard of GMAT Club ? So if you go there. So GMAT Club is like a, you know, it's, it's, it's, it's a big forum for the GMAT takers And there you will see a lot of reviews from about EG Mat and from our EG Mat.
# Prospect:
# Matt, so basically I have completed my B.Tech engineering in Electronics and Communication in 2021. So after that I have joined PwC India and I have been doing, I've been working there for two years, 11 months and after that I have taken 1 sabbatical leave and currently I am on that sabbatical leave from last year July. It was the reason I will tell you it was that I wanted to work, I mean prepare for the UPSC examination that is conducted in India. So I have prepared for that exam and by now since it's 7 to 8 months have gone and I thought that it would be better if I have the option of preparing for the CAT as well. And then I did write the CAT exam into that exam and now I'm quite interested in I'm going for the business courses that is in management courses. So I mean, I have got certain level of interest in it. And then I thought since the CAT and that was not the level I expected, the scores were not according to my expectation. I thought it would be better if I give the GMAT now since I have time and I am currently on the sabbatical and mostly I think four to five months would be enough. I mean, I would, I'm not sure about that. Yeah, Indian School of Business, yeah, ISB as well. So I was looking at the best course materials and the mock test that are provided by various institutes. Initially I was looking at the institute that were giving course materials for the CAT, but later I found out that they were not up to the level that is required for GMAT. And then I found that there is there are some of this like the I believe that it is Manhattan Review, then Wardosh. And then I came to know about this one. And then I did a comparative analysis of the two to three of them. And I found that mostly reviews are positive for EG Mat. Somebody told me yesterday, I, I went to chat GP to find out about you guys. No, I was actually looking at the Cora reviews. I mean, I'm not sure in cases it might be biased, it might be not biased, but yeah, that is the I think that is the most available option I had, right. Yeah, I have heard about it, but not have much acquaintance with it. I just look at the website once or twice, Right, Right.
#
# Prospect’s performance
# Agent:
# So, and that's a very authentic place because GMAT Club does not allow anybody to post a review unless they submit their original scorecard. So it's authenticated and absolutely, you know, legit, that's what I can say. So yeah, that that would be one place where you can look up what's the target score that you're looking at. That would be the score that would mostly surprise, right, 705 should be a good score for your one AMBA to the Iims and yeah and and so you are ready to put in four to five months for your preparation, right? Otherwise, the other websites or the other, I mean, there's coaching materials, providers are charging exorbitant fees. And also that is mostly difficult for an Indian, you know, because the dollar rates are going up daily. They're crazy, isn't it? It's crazy to see that. Yeah. , are you from West Bengal, Right? Where are you situated now? It's nearby. It's in Hooghly district. Hooghly district? No Bengali as well. Absolutely. So I know that that sound, you know, when people speak. Yeah. So accent. Yeah. Yeah. So that's why I could I could tell that. OK. You're probably from West Bengal. All right. So , any mock tests that you have taken for GMAT? You haven't taken any any preparation. That has gone nothing at all, right? No, nothing. I mean, this is your first, Yeah. CAT and ZAT exam preps were done. Been to GMAT preparation. Got you, got you. And so you were saying that quant is an issue for you, right? Right. Yeah. So giving you a bit of background on this, I I just told you that I have written the CAT and as well as the ZAT exam. Got you, got you. So GMAT want is not that difficult, but GMAT verbal is more difficult than the cat verbal and BI section. So yeah, we will it just kind of balances out and we'll look into all of that. And of course, we have a way way to prepare our students for that. OK, so mantra in any case, I think that given that you this is your first time preparing for GMAT. So I will first give you a demo of a of a study plan that we create at our at our website now and then I will give you a walkthrough of the entire course. So let me just get there and I'll share my screen with you in a bit. And so here we are. All right, let's just get in there. So at some point , while you are, you know, still making that decision, just go to EG map platform and take that mock test. The first mock test is free of cost. And so that way you will also get a little feel of GMAT. And what it'll what it'll do is that your score will start as a starting ability for us to see, like how much time do we need with you in order to work? I think four months should be good enough for you. That's not a problem at all. But yeah, let me start sharing my screen. But, you know, it's always good to take a mock test and then proceed from there. But in any case, we will have to start with the basics of the course. But still, it's, it's just a good starting point. Or if you want to, you know, save your mock, you can do that. Also, we can use all the five mocks at the end of the course. OK, so there will be the five mocks that would be provided, the five full length mocks that we have and then there will be. OK, there will be 5 full length mocks, 50 sectional mocks that we will have and apart from that when you buy a course from EGMAT, we also give you 37 sectional mocks from GMAT club. So that will make total of 80, 7 sectional mocks for you and then five full length mock tests, which is I think pretty good to practice. And then we have other, we have total 5500 questions on our platform . So if you just buy this course, you don't need to buy anything else. You don't even have to buy official guides, those question banks. I mean, you can always go to GMAT club and practice questions from there. You really need not buy them. So let's just say creating a new plan. So I'll just tell you how the planner works. OK, so here we are. So this is the planner I created for somebody yesterday, . And so this person is at 475 wh ...
# Prospect:
# So I think based on the institutes that I am trying to get, it would be near about 700. Yeah, right. Because I was looking at the course that EEG might provides that is of the four months and I think going by the prices that would be the mostly the economic option for me, correct, correct. Yeah, Yeah. Yes. Calcutta. No, not in Calcutta. I'm from Calcutta, Born, brought up, raised. So yes, I'm an out and out Kolkata girl. I I'm in Sham Bazaar, Richila Manit Akono Archie like my my place is in Shasham Bazaar. I can read, write and speak. That was my third language, Yes. So, you know, and that's why I can figure out like when people speak. No, for GMAT I haven't taken. I haven't right. So on those I was able to score, I'm in over 90 percentile in the verbal section that is in VI part. But the problem was with the quant section where I faltered in both of them and it pulled my score down. And so I've spoken to a lot of people coming after coming to coming to prepare for GMAT, after giving their cat and they all told me that, you know, compared to GMAT, the cat quant is more difficult. OK, Why my own teams? Oh no, actually not because I don't have your scores.
#
# Agent drawing up plan
# Agent:
# They are called number properties, word problems and advanced topics. So arithmetic actually covers a lot of topics inside it. And so our quant course is actually very tedious. It's a long course and then in DI you have 4 subsections to deal with DSGITA, MSR and TPA. So let's get started with verbal because that's the shortest course to, to master. And this is what your planner will say that OK, if you're starting from today, you start studying from today, then you know, you start with master comprehension course. And then master comprehension course is an additional course, , which actually teaches you how to read because well, I, I am majorly a verbal expert. And so when we finished our verbal offering to the students, we decided that hey, we should teach them how to read. Because generally what happens in verbal is that people come back to reread the passage to answer every question, be it your RC passage or CR passage. So if that is the thing, then we need to cut down on that time and teach them how to read properly. So that's what you see that your course is starting with master comprehension course, which requires you 7 hours to put in your thing. Now would it be 7 hours for you? I'm not sure because you are already doing pretty well in verbal. It's the quant that is, you know, kind of posing issues with you. So once you give the mock and I have your scores from there, then it will be easier for us to determine whether you really need to spend this kind of a time on your verbal or not. For example, you see this person was struggling, I mean they are start struggling with their CR. So they are recommended to do the CR course in 48 hours. May not be the case with you. Probably you're already doing pretty good with CR and instead of 48 hours, you actually need to spend just about 32 or 33 hours, right? So the planner will actually show you the time and account for every single day according to your starting ability. And that's why MOB becomes a little important. Any questions over here, ? No, it's absolutely automated. It is exactly the way mock test official mock tests work. So the entire test is going to be adaptive, OK. And you can select the section. If you you can select your section whether you want to take want first, you want to take DI 2nd and like how in whichever order you want to take. If you do not decide your order, then the default order will be quant, verbal, NDI, OK with a 10 minute break in between somewhere again so you can decide how you want to put your break and in which order you want to take. The test is going to be adaptive as you know it's going going to give you the real GMAT feel and scores will be immediately shown to you so much so that your report card will also be ready right after that where you can see that which questions did you get wrong? How much time did you get? You know, let me show you this real quick. So if I were to show you what all you will see once you do your mock test, it's better that I show you this person's account open up. OK, thank you. So this is going to be your. So this is how you're going, how it's going to look, right? When you start your mock, it will ask you for your target score. And when you finish your mock, it will also give you this thing that, OK, you are this much behind from your target score, right? So this is what's it's going to be. And then you will see that, OK, this is your sectional performance. In verbal, you have 80, which is 60th percentile. In quant, you have 77, which is 46 percentile. In Data Insights, you have 76, which is 58 percentile, and then you can actually click on this Analyze verbal section over here and then it will give you everything, OK, you've gotten in CR, you've gotten 68, so you need to get to 93. In RC, you've gotten 58. You need to get to 96. When you analyze the raw data, then everything will be. Invisible to you that so it will also tell you, OK, this was the split of your question. 23 out of 23 questions, 11 were critica ...
# Prospect:
# I have been working with EG MAP for the last 13 1/2 years. Yeah, so I mean I would be giving the mock then within maybe today or tomorrow whenever I get the time I would attain the mock test. And so it will be is it going to be an auto generated report that will open up after I give the mock or will you and the team would put airport and then would come up with this one. I mean, how I will get this plan? Sure. Any questions before I move further ? Nothing from here, I mean just one thing I saw on the screen. Very nice.
#
# Explaining product
# Agent:
# But wherever she's gotten 75, you know, it's just 1-2. Third is covered, 1/3 actually 1/4. 1/4 is not. 1/4 is not covered. So yeah, these are basically according to the score that you have or that she has gotten basically. But the idea is that should you be getting 100% in all the quizzes otherwise it will not be considered a good score. Well, that is not the case. Your score will be considered good if you stay above the median for that particular quiz. Now you can ask Sushruta, how do I know what is the median for these quizzes and how much is my target? So in order to know that, I'm gonna show you something right now you are looking at the course in the modules view and that's why you can see all the modules that CR course has, right? But there is another view over here which is called the journey view. When we click on journey view, we don't see modules anymore. Now we see the learning levels in our CR course and you can see that how students are graded over here. OK, Your idea is to get grade A in all these learning levels and how to make how to get to grade A, How do I know that I've gotten grade A or how to get grade A? This is where all the median scores for that particular lesson or that particular quiz in that lesson has been mentioned, right? So for the first one, it's 80%. Whenever you score more than the median, you are given grade A. When you score equal to the median, that's when you earn grade B Falling below the median will give you grade C, which is a big red flag. We shouldn't be getting grade C. If grade C happens, then you have two options to work on . The first would be is that you will be given a mentor the moment you decide to come on board, EG MAP. So you're not alone in this journey. There is always a mentor who's looking at your performance and keeping track of things that you're doing on the platform so that whenever you need their help, they can always diagnose your performance and they can come up with proper solutions for you. So you can reach out to them and say, hey, listen, I was doing pretty good with my first 6-7 lessons, but in my 8th lesson, I suddenly got grade C. Can you please evaluate and tell me what do I, what did I not do correctly and how to fix this? So your, you know, mentor will again get back to you saying, hey, this was the thing, this was the thing, you did not do this right. You did not do this right. Do these things and things will be fine. That's one way of doing it. Another thing of doing is self-assessment. In self-assessment, what you will do is that take a look at the solution of that question that you might have gotten wrong and or maybe questions that you might have gotten wrong and compare your process with the process or compare your solution with the solution given in the in the course and then compare that. What is it that you missed out on which made you choose incorrect answer choices? You can create a error log at this point in time also to make sure that, OK, I missed out this thing in this question, I'm not supposed to do this. This is the fixing point and all of that. When you do this exercise, it's just that you become more aware of your weaknesses. And when you attempt the next lesson or the next quiz with the awareness of the weakness, you will be conscious not to repeat that error. And so your accuracy will always, your accuracy will already improve if we have this thing. So this is how we will go about getting grade A from one lesson to another, keeping above the median. Always remember , that Stage 1 is the stage where we are learning all the concepts and we are learning the processes. So any course correction that has to happen will happen in stage 1 because stage 2 and Stage 3 are just our practice stages. The the stage 2 is not the stage where we learn anything or there is a scope for course course correction. Let's just learn things very nicely over here and then let's just, you know, do our practice really, really nicely to improve our accuracy an ...
# Prospect:
# Like what am I really targeting for to achieve? OK, yeah. So will I be provided with one mentor from the initial stages or I have to, I mean, put somewhere that I have problem here and please assign me a mentor. Like how is it work, right? From where did I make this mistake? So one thing, let's say in the diagnostic quiz gives me a green signal that I can go ahead skipping those below concepts. But let's say I want to look at the concepts so that it would help me brush up once again. And if I have something lacking, I can cover the gap there. Will it they be available to me if I want or yes. OK, yeah. What is my section? How shall I be writing my G match really to make the maximum out of my strengths. So one of the question here that I saw in the stage two of all of those, there were something platinum written by the side of it. Also another thing I was thinking as you said, the planner Will most likely do a plan that includes first the verbal section, then the quants and then DI or maybe any other way around. But right, let's say I am doing the verbal or the quant at the very beginning and it's, I mean, for 1 1/2 months or two months, I'm doing the other things. And I got totally cut off from the concept that I learned on, I mean, 1 1/2 months ago. So is there any possibility that a plan be made where, I mean, concepts and practices would be juggled between the coherence and then, right, different sections. Your point is absolutely valid that now that I'm going to spend next four weeks on verbal, what happens to my quant practice and the quant processes that I have learned? I just need to I think I can do it from here. Yeah, sure. My battery is running low and for some reason user is not charging. So yeah, that is basic basically not very much of the questions that I had. Now what I would ask you that let's say I am able to commit 5 hours a day right daily. I mean, I won't overcome it that I would be giving 7 to 8 hours, then things not happen the right way. So let's say I'm taking an average 5 hours a day and how much would it take to complete the preparation in that case?
#
# Price discussion
# Agent:
# So you will be, yeah, giving 35 hours every week right now, right. It could be so that you can do, you can do, you will take anything between two to four months to finish your course. But then again, , one thing we'll have to keep in mind is that I still don't know your starting ability. So so you know, what you can do is that you can start your preparation. You know, let's just go buy a 2 month course. OK, given the fact that you are doing this, you you'll have to start with your basics, Quan basics to Shuru karna here. We'll have to start from Quan. There's no two ways about it. You can go ahead, buy a 2 month course and start preparing and then you know, we can look into if you need any extension. Then you can always get extensions. There are extensions available and you will say that, OK, 15 days extension costs you $49. One month extension costs you $89.00. So what do you want to do? Otherwise, one thing you can do is that you can say, hey, listen, I don't want to get into the trouble of extensions. Now I'm gonna work out a little math for you, , because you're on sabbatical, I think I I can offer you a discount on both the courses. OK, OK, so say the two-month course costs you 199. OK, and the four month course costs 299. OK, suppose you buy a 2 month course and you get extension. Say you think that. Oh no, you know, maybe your planner says you need 8. You need four more weeks or five more weeks to prepare and you get an extension for $89.00 and so your three month course will be valid for which you would be paying $288 for the four month course which is for 299. I can give you a discount of $50 on that and you can have the course for $249 and remain retain the course for four months. And so that way you will not be rushed to do your preparation and you will not also have that tension of kind of extending and doing this and that also. So that is also one of the options. Yes, there can be a discount on the two-month course. So even then, your two-month course plus one month extension in case if you need to do that, you will be paying $248. But if you pay $249, your course will be valid for four months without having to worry about any extensions or whatsoever. So this is how the math work out. You can take, you can think about it and then let me know. But yeah, once we get a mock from you then we will be more confident about the kind of time that you would require to get from your starting ability to seven O 5. OK. So you are basically suggesting that first I take the mock and then I go ahead with buying the course. You buy a 249 course for four months and you save that free mock so that by the end of your course you have all the five mocks. OK. Otherwise what you can do is that you can take a mock and I can create a study plan for you and then you can decide whether you want. I mean, extensions are always you know, you have to reach out to the team and then they will have to do extension, you'll have to pay again and so on and so forth. So it does not even put a pressure on you to take a mock like immediately. But you can still go ahead and take a mock and then we can create a planner for you. But you know that you will not have to waste any more day waiting to buy the course. You know, after you do your mock and stuff, you can go ahead, make the purchase and then you can start, start preparation right away. That's gonna be the thing. The planner will be there. I mean, we can just create the planner for you. Sure that works fine. So every single section is 45 minutes. So you have 45 into 3, OK. And plus you have a 10 minute break in between the sections so you can decide whenever you want to take your break. So this will take you approximately 2 hours to finish everything. Got it. So yeah, that would be pretty much fine. So I would take them off test tomorrow and then yeah, I will go ahead. Start with the preparation right so let me know Sumanto , because if you plan to go with the four month course, the discount will pr ...
# Prospect:
# OK, I have to appear on the test. I mean, it's good. Let me just buy the four month course. Now you can also say that OK, you're giving me a discount on four month course. Will not there be any discount on one month course? Say I take out $40 from that. I mean the the thing you are suggesting most likely looks as well as what I thought out that four months would be the yeah, I mean most optimal thing as well as it would be the most economic thing from all points of view if I correct, correct. I would also so see there are there are two things to that. I think a four month course will be OK. But I think that a four month course works out on all the way. And the plan will also be in front of me, right? I believe so I would attend the mock test most likely by tomorrow I will get some free time tomorrow. So I how much long is it? I'm, I mean, I'm don't have much idea about the length of the GMAT test. You can go ahead and purchase the course in that isn't analog to tell you that is not on the website Yeah, I, I will definitely need the code from you right, right. OK, sure, definitely makes sense. OK, so round one, round two, round three, I didn't get it.
#
# Q&A
# Agent:
# And so there is a cutoff for filing your application for round two also. Then again, the filtration will happen, the sorting will happen and they will fill up as many seats as they can from the from the applications that they get. It could be so that they did not get good enough applications for round two and some seats are still left. So for that they will open up round 3, which will happen somewhere in in January end or something like that. For Indian schools, it's generally like that. So they will open third round and by third round their idea is to you know, just get all the seats filled up. So that is what's going to happen. I will figure that out and I'll let you know. But it's good that you apply in first around itself because then the number of seats are absolutely. I mean, it's it's, it's a it's an open house. So basically ISB does select candidates from GMAT for two years MBA. Absolutely. That is right. Absolutely. Absolutely. ISB is definitely a good one and you can you can take a look at other ones as well and then do your analysis. And then if you feel you're doing so much man at any which way, if you you know, get a two year program, why not to try for that? So that won't correct. Any return on investment would be very less on that correct. Correct. Correct. Absolutely. No, no two ways about that. Yeah. You have to look into your return of investment. So yeah, if you're doing it, then do it from a good school. Makes complete sense. Yeah. Yeah. So that is the thing basically. Good, good. Not an issue at all. OK, So man, just so see what I was telling that yeah, I selected the executive MBA option and that is that was what communicated to you. So yeah, correct. Correct. So yeah. So yeah, that basically that's that's how I got you attended the call and you said that that was your requirement. But I'll keep this thing in mind. Also, I'm putting down in my personal notes that even it's not necessarily that you will go for executive, but you will pay your options for both. And so you will look into the profiles. I'll try and share the profile of some of the good Indian colleges for two year course. So you know, look out for that resource. So that would also be a option I might think about and analyze. But right, yeah, why not? So what I'll do is that I will share those resources with you, you know, resources of the college profiles, some in US, some in Europe and some in India, so that you can do your research. Once you have the baseline knowledge, then you can, you know, find out more a little bit by doing your own search. So I will send those resources with you so that you also have those things to look into. Yeah, you definitely can do that. Yeah. So yeah, first thing is getting a good G math score. Yeah, go ahead. ISB does require exactly the same kind of They will require Sops, they will require letter of recommendation, they will want you to write 2 essays about how you know your achievements and your work, you know, work profile, your leadership qualities, your strengths and your weaknesses and how do you try to overcome them and your purpose of doing MBA so on and so forth. So, so application is almost the same. Yes, the, the content changes a little bit depending upon the depending upon the profile of the college that you're trying to apply for. But for that, you know, application part, basically  people generally work with professional, professional consultants who those who can help you, they will look into your profile, they will assess your profile and they will say, OK, this is what your GMAP score is, this is what your profile is. We will for this college, we will turn your profile in this way for this particular college, we will make it little bit more friendly to that particular college ethics, you know.
# Prospect:
# But do they do it for executive program or not that I will have to figure out whether IIMA and IIMC and ISB does do that. And also I mean, I would consider A2 year MBA as well if I get any good College in India. And I really have a great course. give me SPGN is also there. Yeah, yeah, yeah, SPGN is also there. I was talking to somebody yesterday and they were saying that they want to do their MBA in finance major and so they are actually looking at this PGN for for admissions. Yes, yeah. So basically I think I have knowledge about these two good colleges in India that offer two year MBA based on the GMAT scores. I don't have much idea about what other colleges offer based on the GMAT, if they offer any two year MBA or not. So yeah, that I would also weigh in as an option if I get correct scoring GMAT for the two year NBA as well. If I get any top tier colleges, then it would be worth it. Yeah, yeah, definitely that, yeah. No, no, I I mean, I would consider if it is a good college because see my situation is that I am now I am in PwC India. So that wouldn't be good if I do a two year MBA from any of the Tier 2 colleges. But if I get something like FP, Jan, ISB or let's say Jamnalal Bajaj or XLRI, so that would definitely be a cream institute to, I mean, get into the world of business. But yeah, I would also weigh in if I get good colleges for two year MBA. I'll be I'll be sharing it to you, sharing it because most likely I would be doing it in India because I'm not very much into going abroad, whereas I haven't given, I mean read that thought into that aspect as well. But yeah, I would have to see if I mean, there are good institutes outside India which are really worth it and people go there. But since I have not much idea about the institutes, like I have only heard of a few good institutes like maybe Harvard, Wharton and those schools. But yeah, so other than that, I don't have much more idea. I if I get the knowledge of those, I would be able to understand how I can apply for them. And if I get, I mean, enrolled, get their admission into some good cool, why not? That would also be an option for me, right? So that that is basically all I have. Yeah, Yeah. Sure. One more thing I was saying I what I believe is the process for applying in those schools as well as the profile requirement are totally different from those going to Indian business schools, right? What I understand or is it the application requirement is almost the same? I mean I know about ISB.
#
# Wrap
# Agent:
# So these things happen and there are consultants, there are professional consultants, admission consultants who can do that for you. At the moment, unfortunately, , there are talks that EG Mat will eventually come to that level, come to that point where we will start doing this for our students. But as of now, we don't have that. This is not only ISB, this is not only Indian schools but even US colleges with 685 score, they are not putting your application down. No worries about that. Seven O 5, that's a remarkable good score. Anything above 7 100 in GMAT focus is very, very nice. If you push yourself a little bit, get to 715 of all you know, some scholarship opportunities will also open for you. But there are no scholarships for from Indian colleges. You will you will get some scholarship in the in the US colleges if you get to 7715. So yeah, GMAT is the first thing like a good GMAT score can open up a lot of avenues for you for sure. Got it. We'll purchase the course. Yeah, go ahead and we'll come again to you to understand how I can go ahead after that. Absolutely, absolutely. There will be your mentors who would be working for you. But you have my number if you want to, you know, just want to talk about something and get a little more idea. We can always do that. Not an issue. Great. All righty. Yeah. OK. Have a great rest of your day and bye for now. Yeah. Same as well.
# Prospect:
# OK, So is that provided by EV MAT or not? So sorry about that. No worries if I if I I mean I believe 700 around would be a score to get around in good institute in India as well as absolutely 685 is the median score for all the colleges across the globe. Very, very nice. So yeah, let's see, I will attend the mock test tomorrow. And yeah, if I get to 685 around and yeah, if 7700 plus, then yeah, I would. Sure. Thank you. Thanks so much for your time, Sumanthir. Thank you so much for. Yeah, yeah. Thank you. Bye. Bye. Bye. Thank you.

# %%
with open("transcript_texts_80.json", "w", encoding="utf-8") as f:
    json.dump(simplified_data, f, ensure_ascii=False, indent=2)
